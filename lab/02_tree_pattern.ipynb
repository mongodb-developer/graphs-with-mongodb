// %% [markdown]
// # Using the Tree Pattern
//
// ## Overview
//
// The **Tree Pattern** works best when your graph is (or can be simplified into) a hierarchy.
// Each document stores an `ancestors` array listing all nodes above it in the tree.
// This trades write cost for extremely fast, **single-query, index-backed** reads — no `$graphLookup` needed.
//
// ### The hierarchy (database: `tree_lab`)
//
// The five data centers form a rooted tree.  Routers and network cards inherit
// the full ancestor chain of their parent DC.
//
// ```
// dc1  ← root  (ancestors: [])
// ├── dc2       (ancestors: [dc1])
// │   ├── r3, r4              (ancestors: [dc1, dc2])
// │   │    ├── nc4, nc5       (ancestors: [dc1, dc2, r3])
// │   │    └── nc6            (ancestors: [dc1, dc2, r4])
// │   ├── dc4  (ancestors: [dc1, dc2])
// │   │   ├── r7, r8          (ancestors: [dc1, dc2, dc4])
// │   │   │    ├── nc10, nc11 (ancestors: [dc1, dc2, dc4, r7])
// │   │   │    └── nc12       (ancestors: [dc1, dc2, dc4, r8])
// │   └── dc5  (ancestors: [dc1, dc2])
// │       ├── r9, r10         (ancestors: [dc1, dc2, dc5])
// │       │    ├── nc13, nc14 (ancestors: [dc1, dc2, dc5, r9])
// │       │    └── nc15       (ancestors: [dc1, dc2, dc5, r10])
// └── dc3  ← leaf (ancestors: [dc1])
//     ├── r5, r6              (ancestors: [dc1, dc3])
//     │    ├── nc7, nc8       (ancestors: [dc1, dc3, r5])
//     │    └── nc9            (ancestors: [dc1, dc3, r6])
// └── r1, r2                  (ancestors: [dc1])
//      ├── nc1, nc2           (ancestors: [dc1, r1])
//      └── nc3                (ancestors: [dc1, r2])
// ```
//
// ### Data model
//
// | Collection | Key fields |
// |---|---|
// | `data_centers` | `_id`, `parent`, `ancestors` |
// | `routers` | `_id`, `data_center`, `ancestors` — inherits full DC path |
// | `network_cards` | `_id`, `router`, `ancestors` — inherits full DC path + router |
//
// ### Why it's fast
//
// MongoDB creates a **multi-key index** on the `ancestors` array.
// A query like `find({ ancestors: 'dc2' })` hits that index and returns **all** descendants
// (including dc4, dc5, and everything under them) in a single scan — no recursion, no joins.

// %% [markdown]
// ## Setup — connect to MongoDB

// %%
import { MongoClient, Document } from 'mongodb';

interface NetDoc { _id: string; [key: string]: any; }

const uri = process.env.MONGODB_URI ?? 'mongodb://admin:mongodb@localhost:27017/?directConnection=true';
const client = new MongoClient(uri, { appName: 'devrel-workshop-mongodb-graphs' });
await client.connect();

const db = client.db('tree_lab');
const dataCenters  = db.collection<NetDoc>('data_centers');
const routers      = db.collection<NetDoc>('routers');
const networkCards = db.collection<NetDoc>('network_cards');

const counts = {
  data_centers:  await dataCenters.countDocuments(),
  routers:       await routers.countDocuments(),
  network_cards: await networkCards.countDocuments(),
};
console.log('Connected to tree_lab. Document counts:', counts);

// %% [markdown]
// ## Explore the documents
//
// Note how `ancestors` encodes the full path from the root, growing deeper as you go down the tree.

// %%
const dc1  = await dataCenters.findOne({ _id: 'dc1' });
const dc5  = await dataCenters.findOne({ _id: 'dc5' });
const r7   = await routers.findOne({ _id: 'r7' });
const nc12 = await networkCards.findOne({ _id: 'nc12' });

console.log('dc1 (root):          parent =', dc1!.parent,  '  ancestors =', dc1!.ancestors);
console.log('dc5 (depth 2):       parent =', dc5!.parent,  '  ancestors =', dc5!.ancestors);
console.log('r7  (dc4 router):    ancestors =', r7!.ancestors,  '  ← full DC path');
console.log('nc12 (r8 NIC):       ancestors =', nc12!.ancestors, '  ← DC path + router');

// %% [markdown]
// ## Find all descendants of dc2 — a subtree query
//
// dc2 has two DC children (dc4, dc5) plus its own routers and NICs.
// A single indexed `find({ ancestors: 'dc2' })` reaches all of them at every depth.

// %%
// dc2's subtree: dc4, dc5 are children → their routers and NICs are also descendants
const dcChildren   = await dataCenters.find({ ancestors: 'dc2' }).sort({ _id: 1 }).toArray();
const routersInDc2 = await routers.find({ ancestors: 'dc2' }).sort({ _id: 1 }).toArray();
const cardsInDc2   = await networkCards.find({ ancestors: 'dc2' }).sort({ _id: 1 }).toArray();

console.log('Child data centers of dc2:');
dcChildren.forEach(dc => console.log(`  ${dc._id}  "${dc.name}"  ancestors=${JSON.stringify(dc.ancestors)}`));

console.log(`\nRouters (${routersInDc2.length}):`);
routersInDc2.forEach(r => console.log(`  ${r._id}  ${r.hostname}  ancestors=${JSON.stringify(r.ancestors)}`));

console.log(`\nNetwork cards (${cardsInDc2.length}):`);
cardsInDc2.forEach(nc => console.log(`  ${nc._id}  ${nc.serial_number}  ancestors=${JSON.stringify(nc.ancestors)}`));

// %% [markdown]
// ## Verify the index is being used
//
// `.explain('executionStats')` shows MongoDB uses the `ancestors_1` multi-key index —
// even when the subtree spans multiple DC levels.

// %%
const explanation = await networkCards
  .find({ ancestors: 'dc2' })
  .explain('executionStats') as Document;

const stage       = explanation.executionStats;
const winningPlan = explanation.queryPlanner?.winningPlan;

console.log('Index used?      ', JSON.stringify(winningPlan, null, 2).includes('IXSCAN') ? 'YES — IXSCAN' : 'NO — COLLSCAN');
console.log('Docs returned:   ', stage?.nReturned);
console.log('Docs examined:   ', stage?.totalDocsExamined);
console.log('Keys examined:   ', stage?.totalKeysExamined);
console.log('\n→ docsExamined equals nReturned — the index does all the work, no extra scan.');

// %% [markdown]
// ## dc3 is a leaf — its subtree is shallow
//
// dc3 has no child DCs (only routers + NICs). Compare its subtree size to dc2's.

// %%
const dc3Children  = await dataCenters.find({ ancestors: 'dc3' }).toArray();
const dc3Routers   = await routers.find({ ancestors: 'dc3' }).sort({ _id: 1 }).toArray();
const dc3Cards     = await networkCards.find({ ancestors: 'dc3' }).sort({ _id: 1 }).toArray();

console.log(`dc3 child DCs : ${dc3Children.length}  (none — dc3 is a leaf)`);
console.log(`dc3 routers   : ${dc3Routers.length}`);
dc3Routers.forEach(r => console.log(`  ${r._id}  ${r.hostname}  ancestors=${JSON.stringify(r.ancestors)}`));
console.log(`dc3 NICs      : ${dc3Cards.length}`);
dc3Cards.forEach(nc => console.log(`  ${nc._id}  ${nc.serial_number}  ancestors=${JSON.stringify(nc.ancestors)}`));

console.log('\n→ dc2 subtree had 6 routers + 9 NICs; dc3 has only 2 + 3 because it has no child DCs.');

// %% [markdown]
// ## Full inventory of the dc1 subtree — the entire network
//
// Because dc1 is the root, `ancestors: 'dc1'` returns every router and NIC in the topology.

// %%
const allRouters = await routers.find({ ancestors: 'dc1' }).sort({ _id: 1 }).toArray();
const allCards   = await networkCards.find({ ancestors: 'dc1' }).sort({ _id: 1 }).toArray();

console.log(`Total routers under dc1 (root): ${allRouters.length}  — every router in the network`);
console.log(`Total NICs    under dc1 (root): ${allCards.length}   — every NIC in the network`);

const totalPorts = allCards.reduce((sum: number, nc: Document) => sum + nc.port_count, 0);
console.log(`Total network ports across all DCs: ${totalPorts}`);

// Show depth distribution of ancestor arrays
const byDepth: Record<number, number> = {};
allCards.forEach(nc => {
  const d = nc.ancestors.length;
  byDepth[d] = (byDepth[d] ?? 0) + 1;
});
console.log('\nNIC ancestor-array depth distribution (= tree depth):');
Object.entries(byDepth).sort().forEach(([d, n]) => console.log(`  depth ${d}: ${n} NICs`));

// %% [markdown]
// ## Compound query: high-speed NICs anywhere under dc2
//
// Because dc2's subtree includes dc4 and dc5, one query on `ancestors: 'dc2'` naturally
// covers Denver and Dallas — without listing them explicitly.

// %%
// dc2 subtree = dc2 itself + dc4 (Denver) + dc5 (Dallas)
// One filter covers all three DCs — no need to list them
const highSpeedDc2 = await networkCards
  .find({ ancestors: 'dc2', speed_gbps: { $gte: 100 } })
  .sort({ _id: 1 })
  .toArray();

console.log(`High-speed NICs (≥100 GbE) anywhere under dc2 (${highSpeedDc2.length}):`);
highSpeedDc2.forEach(nc => {
  console.log(`  ${nc._id}  ${nc.serial_number}  ${nc.speed_gbps} GbE  ancestors=${JSON.stringify(nc.ancestors)}`);
});

console.log('\n→ Results span dc2 (LA), dc4 (Denver), and dc5 (Dallas) — all reachable via one ancestors match.');

// %% [markdown]
// ## Key Takeaways
//
// | Aspect | Tree Pattern |
// |---|---|
// | **Best for** | Hierarchies that can be expressed as a rooted tree (org charts, location trees, product categories) |
// | **Subtree query** | `find({ ancestors: 'nodeId' })` — single indexed read, any depth |
// | **Index type** | Multi-key index — one entry per element in the `ancestors` array |
// | **No `$graphLookup`** | Ancestry is pre-materialised; traversal happens at write time, not query time |
// | **Write cost** | Moving a subtree requires updating `ancestors` on every descendant |
// | **Depth** | Unlimited — the full path is stored in the array |
// | **Limitation** | A node can only have one parent chain; true many-to-many graphs (like the `graph_lab` topology) cannot be faithfully expressed as a single tree |
//
// > **Graph → Tree trade-off**: the `graph_lab` data centres are a mesh (dc3 connects to both dc1 and dc4).
// > In `tree_lab` we chose a single canonical path — dc3 hangs off dc1 only.
// > Cross-links are dropped; in return every subtree query becomes a trivial index lookup.

// %%
await client.close();
console.log('Connection closed.');
